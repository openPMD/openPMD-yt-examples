# %%
import yt

# %%
from numpy import *

# %%
import sys
print(sys.path)
# Out:
# ['', '/home/fwktg1/.local/lib/python2.7/site-packages/pyzmq-15.2.0-py2.7-linux-x86_64.egg', '/home/fwktg1/.local/lib/python2.7/site-packages/tornado-4.3-py2.7-linux-x86_64.egg', '/home/fwktg1/.local/lib/python2.7/site-packages/backports_abc-0.4-py2.7.egg', '/home/fwktg1/.local/lib/python2.7/site-packages/certifi-2015.11.20.1-py2.7.egg', '/home/fwktg1/.local/lib/python2.7/site-packages/singledispatch-3.4.0.3-py2.7.egg', '/home/fwktg1/.local/lib/python2.7/site-packages/backports.ssl_match_hostname-3.5.0.1-py2.7.egg', '/home/fwktg1/.local/lib/python2.7/site-packages/Cython-0.23.4-py2.7-linux-x86_64.egg', '/bigdata/hplsim/external/fwktg1/yt/openPMD-yt', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/distribute-0.6.28-py2.7.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/matplotlib-1.4.2-py2.7-linux-x86_64.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/mock-1.0.1-py2.7.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/nose-1.3.4-py2.7.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/pyparsing-2.0.3-py2.7.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/pytz-2014.10-py2.7.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/python_dateutil-2.2-py2.7.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/Cython-0.21.1-py2.7-linux-x86_64.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/Jinja2-2.7.2-py2.7.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/MarkupSafe-0.23-py2.7-linux-x86_64.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/numexpr-2.2.2-py2.7-linux-x86_64.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/simplegeneric-0.8.1-py2.7.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/pydicom-0.9.8-py2.7.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/netCDF4-1.1.1-py2.7-linux-x86_64.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/h5py-2.3.1-py2.7-linux-x86_64.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/joblib-0.8.4-py2.7.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/tofu-0.9-py2.7.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/pcircle-0.15rc1_1.g705f198-py2.7.egg', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/pandas-0.17.1-py2.7-linux-x86_64.egg', '/opt/pkg/devel/python/2.7.8/bin', '/home/fwktg1/.local/lib/python2.7/site-packages', '/opt/pkg/devel/python/2.7.8/lib/python27.zip', '/opt/pkg/devel/python/2.7.8/lib/python2.7', '/opt/pkg/devel/python/2.7.8/lib/python2.7/plat-linux2', '/opt/pkg/devel/python/2.7.8/lib/python2.7/lib-tk', '/opt/pkg/devel/python/2.7.8/lib/python2.7/lib-old', '/opt/pkg/devel/python/2.7.8/lib/python2.7/lib-dynload', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages', '/opt/pkg/devel/python/2.7.8/lib/python2.7/site-packages/IPython/extensions']

# %%
"""

Programm: YT_Example_Plots
Author: Daniel Grassinger
License: Modified BSD License (also known as New or Revised BSD)
Date: 25.09.2015
Python: 2.7.6
YT Version: 3.2

Description: This file show some examples how to plot data in yt

more examples and docomentation on:
http://yt-project.org/doc/visualizing/

Required: an example openPMD called "data00000800.h5" file must
          exitst in the same folder

"""

import yt
import numpy as np
import h5py
import math


# load an example dataset
ds = yt.load("/home/fwktg1/openPMD-example-datasets/example-3d/hdf5/data00000500.h5")

#First some general informations on the dataset

print "1: General Informations:"
ds.print_stats()

print "   This Fields does yt know or could generate them"
ds.field_list

print "   Size of Simulation Box: "
print ds.domain_width

# This returns the data of this field as a YTArray with units
print "   The Data and Units of the Field E_x"
ad = ds.all_data()
print ad["E_x"] 

#First simple plots
print "2: Simple Plots"

print "   Projection Plot of E_x"
p = yt.ProjectionPlot(ds, "y", "E_x")

# This adds a Title to the Plot
p.annotate_title('Projection Plot of E_x')

# Shows the Plot on Screen
p.show()
# Saves the Plot as .png
p.save()

# This makes a SlicePlot of rho and overplot the contur of E

# This Function discribes how E is calculated out of E_x, E_y, E_z
def _absE_x(field, data):
    return np.sqrt(data["E_x"]*data["E_x"]+data["E_y"]*data["E_y"]+data["E_z"]*data["E_z"])

# Here E is defined as a new Field called "absE_x"
ds.add_field(("openPMD", "absE_x"),function=_absE_x,units="V/m")

# This makes a SlicePlot of rho
p = yt.SlicePlot(ds, "y", ['rho'])

# This overplots the contur of E
p.annotate_contour(("openPMD","absE_x"),ncont=5, clim=(1e12,1e11))
p.show()

# There are a lot of another annotations and additional parameters for the visualisation on the yt website

#Plotting time series
print "3: Plotting time series"

# Only load with yt.load but use ? or * instead of characters creats a time series
timeseries = yt.load("/home/fwktg1/openPMD-example-datasets/example-3d/hdf5/data0000??00.h5")

# Get every dataset from timeseries and plot it
for ds in timeseries:
    p = yt.SlicePlot(ds, "y","E_x") 
    p.show()

# Volume Rendering of 3D Data
# As OpenPMD 3D Datasets are not tested yet we use other sample Data
#Sample Data from http://yt-project.org/data/
ds = yt.load("/bigdata/hplsim/external/fwktg1/yt/IsolatedGalaxy/galaxy0030/galaxy0030")

#This creates and shows a 3D Model of the sample Data
print "4: Volume Rendering of Example Galaxy"
tf = yt.ColorTransferFunction((-28, -25))
tf.add_layers(4, w=0.03)
cam = ds.camera([0.5, 0.5, 0.5], [1.0, 1.0, 1.0], (20.0, 'kpc'), 512, tf, no_ghost=False)
cam.show(clip_ratio=4.0)
# Out:
# yt : [WARNING  ] 2016-01-29 11:26:17,886 openPMD: found 1 iterations in file
# yt : [WARNING  ] 2016-01-29 11:26:17,886 openPMD: only choose to load first iteration in file
# yt : [INFO     ] 2016-01-29 11:26:17,925 Parameters: current_time              = 1.6423560726e-13
# yt : [INFO     ] 2016-01-29 11:26:17,925 Parameters: domain_dimensions         = [ 26  26 201]
# yt : [INFO     ] 2016-01-29 11:26:17,926 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2016-01-29 11:26:17,927 Parameters: domain_right_edge         = [ 1.  1.  1.]
# yt : [INFO     ] 2016-01-29 11:26:17,927 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2016-01-29 11:26:17,929 openPMD: found 1 iterations in file
# yt : [WARNING  ] 2016-01-29 11:26:17,930 openPMD: only choose to load first iteration in file
# yt : [WARNING  ] 2016-01-29 11:26:17,932 openPMD: found 1 iterations in file
# yt : [WARNING  ] 2016-01-29 11:26:17,932 openPMD: only choose to load first iteration in file
# yt : [INFO     ] 2016-01-29 11:26:17,941 Loading field plugins.
# yt : [INFO     ] 2016-01-29 11:26:17,941 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2016-01-29 11:26:17,942 Loaded astro (15 new fields)
# yt : [INFO     ] 2016-01-29 11:26:17,942 Loaded cosmology (22 new fields)
# yt : [INFO     ] 2016-01-29 11:26:17,943 Loaded fluid (64 new fields)
# yt : [INFO     ] 2016-01-29 11:26:17,945 Loaded fluid_vector (96 new fields)
# yt : [INFO     ] 2016-01-29 11:26:17,945 Loaded geometric (112 new fields)
# yt : [INFO     ] 2016-01-29 11:26:17,946 Loaded local (112 new fields)
# yt : [INFO     ] 2016-01-29 11:26:17,946 Loaded magnetic_field (120 new fields)
# yt : [INFO     ] 2016-01-29 11:26:17,947 Loaded my_plugins (120 new fields)
# yt : [INFO     ] 2016-01-29 11:26:17,947 Loaded species (122 new fields)
# 1: General Informations:
# level	# grids	       # cells	     # cells^3
# yt : [INFO     ] 2016-01-29 11:26:18,291 Projection completed
# yt : [INFO     ] 2016-01-29 11:26:18,291 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-01-29 11:26:18,292 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-01-29 11:26:18,295 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-01-29 11:26:18,296 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-01-29 11:26:18,297 Making a fixed resolution buffer of (('openPMD', 'E_x')) 800 by 800
# yt : [WARNING  ] 2016-01-29 11:26:18,349 Plot image for field ('openPMD', 'E_x') has both positive and negative values. Min = -891015870557.733521, Max = 891015870557.773071.
# yt : [WARNING  ] 2016-01-29 11:26:18,349 Switching to symlog colorbar scaling unless linear scaling is specified later
# ----------------------------------------------
#   0	     1	        135876	            52
# ----------------------------------------------
#    	     1	        135876
#
#
# t = 1.64235607e-13 = 1.64235607e-13 s = 5.20431235e-21 years
#
# Smallest Cell:
# 	Width: 1.246e-24 Mpc
# 	Width: 1.246e-18 pc
# 	Width: 2.571e-13 AU
# 	Width: 3.846e+00 cm
#    This Fields does yt know or could generate them
#    Size of Simulation Box:
# [ 1.  1.  1.] code_length
#    The Data and Units of the Field E_x
# [ 0.  0.  0. ...,  0.  0.  0.] V/m
# 2: Simple Plots
#    Projection Plot of E_x
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2016-01-29 11:26:19,301 Saving plot data00000500.h5_Projection_y_E_x.png
# yt : [INFO     ] 2016-01-29 11:26:19,675 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-01-29 11:26:19,675 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-01-29 11:26:19,679 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-01-29 11:26:19,680 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-01-29 11:26:19,681 Making a fixed resolution buffer of (('openPMD', 'rho')) 800 by 800
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-8-41ef97e8c8cf> in <module>()
#      67
#      68 # This makes a SlicePlot of rho
# ---> 69 p = yt.SlicePlot(ds, "y", ['rho'])
#      70
#      71 # This overplots the contur of E
#
# /bigdata/hplsim/external/fwktg1/yt/openPMD-yt/yt/visualization/plot_window.pyc in SlicePlot(ds, normal, fields, axis, *args, **kwargs)
#    2131             del kwargs['north_vector']
#    2132
# -> 2133         return AxisAlignedSlicePlot(ds, normal, fields, *args, **kwargs)
#
# /bigdata/hplsim/external/fwktg1/yt/openPMD-yt/yt/visualization/plot_window.pyc in __init__(self, ds, axis, fields, center, width, axes_unit, origin, fontsize, field_parameters, window_size, aspect, data_source)
#    1272         PWViewerMPL.__init__(self, slc, bounds, origin=origin,
#    1273                              fontsize=fontsize, fields=fields,
# -> 1274                              window_size=window_size, aspect=aspect)
#    1275         if axes_unit is None:
#    1276             axes_unit = get_axes_unit(width, ds)
#
# /bigdata/hplsim/external/fwktg1/yt/openPMD-yt/yt/visualization/plot_window.pyc in __init__(self, *args, **kwargs)
#     667             self._plot_type = kwargs.pop("plot_type")
#     668         self._splat_color = kwargs.pop("splat_color", None)
# --> 669         PlotWindow.__init__(self, *args, **kwargs)
#     670
#     671     def _setup_origin(self):
#
# /bigdata/hplsim/external/fwktg1/yt/openPMD-yt/yt/visualization/plot_window.pyc in __init__(self, data_source, bounds, buff_size, antialias, periodic, origin, oblique, window_size, fields, fontsize, aspect, setup)
#     247                 self._field_transform[field] = linear_transform
#     248         self.setup_callbacks()
# --> 249         self._setup_plots()
#     250
#     251     def _initialize_dataset(self, ts):
#
# /bigdata/hplsim/external/fwktg1/yt/openPMD-yt/yt/visualization/plot_window.pyc in _setup_plots(self)
#     735             return
#     736         if not self._data_valid:
# --> 737             self._recreate_frb()
#     738             self._data_valid = True
#     739         self._colorbar_valid = True
#
# /bigdata/hplsim/external/fwktg1/yt/openPMD-yt/yt/visualization/plot_window.pyc in _recreate_frb(self)
#     307         self._data_valid = True
#     308         if old_fields is None:
# --> 309             self._frb._get_data_source_fields()
#     310         else:
#     311             # Restore the old fields
#
# /bigdata/hplsim/external/fwktg1/yt/openPMD-yt/yt/visualization/fixed_resolution.pyc in _get_data_source_fields(self)
#     156         for f in fields:
#     157             if f not in exclude and f[0] not in self.data_source.ds.particle_types:
# --> 158                 self[f]
#     159
#     160     def _is_ion( self, fname ):
#
# /bigdata/hplsim/external/fwktg1/yt/openPMD-yt/yt/visualization/fixed_resolution.pyc in __getitem__(self, item)
#     135         buff = self.ds.coordinates.pixelize(self.data_source.axis,
#     136             self.data_source, item, bounds, self.buff_size,
# --> 137             int(self.antialias))
#     138
#     139         for name, (args, kwargs) in self._filters:
#
# /bigdata/hplsim/external/fwktg1/yt/openPMD-yt/yt/geometry/coordinates/cartesian_coordinates.pyc in pixelize(self, dimension, data_source, field, bounds, size, antialias, periodic)
#      55         if dimension < 3:
#      56             return self._ortho_pixelize(data_source, field, bounds, size,
# ---> 57                                         antialias, dimension, periodic)
#      58         else:
#      59             return self._oblique_pixelize(data_source, field, bounds, size,
#
# /bigdata/hplsim/external/fwktg1/yt/openPMD-yt/yt/geometry/coordinates/cartesian_coordinates.pyc in _ortho_pixelize(self, data_source, field, bounds, size, antialias, dim, periodic)
#      72                              data_source[field], size[0], size[1],
#      73                              bounds, int(antialias),
# ---> 74                              period, int(periodic)).transpose()
#      75         return buff
#      76
#
# error: data is of incorrect type (wanted 1D float)

# %%
p.save()
# Out:
# yt : [INFO     ] 2016-01-29 11:30:34,501 Saving plot data00000500.h5_Projection_y_E_x.png
# ['data00000500.h5_Projection_y_E_x.png']
